# %% [markdown]
# <a href="https://colab.research.google.com/github/EmmanuelFelipe/curso-extensao-python-2023-1/blob/main/projeto_filmes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Projeto teste utilizando a base movies.xlsx disponibilizado no data.world
#
# https://data.world/jamesgaskin/movies

# %%
import pandas as pd

# %%
movies_df = pd.read_excel("movies.xlsx")
display(movies_df.head())
# Out:
#    MovieID                       Title MPAA_Rating      Budget        Gross  \
# 0      1.0          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1      2.0          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2      3.0              Turner & Hooch          PG  13000000.0   71079915.0
# 3      4.0  Born on the Fourth of July           R  14000000.0  161001698.0
# 4      5.0             Field of Dreams          PG  15000000.0   84431625.0
#
#   Release_Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# ...

# %%
# Criar uma coluna "Obs" que tenha nela escrito "ALTO CUSTO" quando a coluna Budget for maior que 10000000.0
movies_df["obs"] = None
movies_df.loc[movies_df["Budget"] > 10000000.0, "obs"] = "ALTO CUSTO"
display(movies_df)
# Out:
#      MovieID                        Title MPAA_Rating       Budget  \
# 0        1.0           Look Who's Talking       PG-13    7500000.0
# 1        2.0           Driving Miss Daisy          PG    7500000.0
# 2        3.0               Turner & Hooch          PG   13000000.0
# 3        4.0   Born on the Fourth of July           R   14000000.0
# 4        5.0              Field of Dreams          PG   15000000.0
# ..       ...                          ...         ...          ...
# 629    631.0                      Encanto          PG  150000000.0
# 630    632.0                         Dune       PG-13  165000000.0
# 631    633.0               No Time to Die       PG-13  250000000.0
# 632    634.0             tick, tick…BOOM!       PG-13   55000000.0
# 633    635.0  Venom: Let There Be Carnage       PG-13  110000000.0
#
#            Gross Release_Date    Genre  Runtime  Rating  Rating Count  \
# 0    296000000.0   1989-10-12  Romance     93.0     5.9       73638.0
# ...
